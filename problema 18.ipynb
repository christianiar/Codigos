# %%
col = []
FILE = open("problema 18.txt", "r")

for blob in FILE: 
    col.append([int(i) for i in blob.split(" ")])

# %%
new_col = []
for k in range(len(col)):
    i = len(col)-k-1
    print(col[i])
    array_temp = []
    num_temp = 0
    for j in range(len(col[i])-1):
        if j < len(col[i-1]):
            num_temp = max(col[i][j],col[i][j+1]) + col[i-1][j]
        else:
            if j == len(col[i-1])-1:
                num_temp = col[i][j] + col[i-1][j]
        array_temp.append(num_temp)
    print(col[i-1])
    print('arr',array_temp)
    if i < 0:
        array_temp.remove(min(array_temp[0]))
    col[i-1] = array_temp
# Out:
# [4, 62, 98, 27, 23, 9, 70, 98, 73, 93, 38, 53, 60, 4, 23]
# [63, 66, 4, 68, 89, 53, 67, 30, 73, 16, 69, 87, 40, 31]
# arr [125, 164, 102, 95, 112, 123, 165, 128, 166, 109, 122, 147, 100, 54]
# [125, 164, 102, 95, 112, 123, 165, 128, 166, 109, 122, 147, 100, 54]
# [91, 71, 52, 38, 17, 14, 91, 43, 58, 50, 27, 29, 48]
# arr [255, 235, 154, 150, 140, 179, 256, 209, 224, 172, 174, 176, 148]
# [255, 235, 154, 150, 140, 179, 256, 209, 224, 172, 174, 176, 148]
# [70, 11, 33, 28, 77, 73, 17, 78, 39, 68, 17, 57]
# arr [325, 246, 187, 178, 256, 329, 273, 302, 263, 242, 193, 233]
# [325, 246, 187, 178, 256, 329, 273, 302, 263, 242, 193, 233]
# [53, 71, 44, 65, 25, 43, 91, 52, 97, 51, 14]
# arr [378, 317, 231, 321, 354, 372, 393, 354, 360, 293, 247]
# [378, 317, 231, 321, 354, 372, 393, 354, 360, 293, 247]
# [41, 48, 72, 33, 47, 32, 37, 16, 94, 29]
# arr [419, 365, 393, 387, 419, 425, 430, 376, 454, 322]
# [419, 365, 393, 387, 419, 425, 430, 376, 454, 322]
# [41, 41, 26, 56, 83, 40, 80, 70, 33]
# ...
